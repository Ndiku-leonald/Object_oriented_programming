# %% [markdown]
# ## inhertnace
# - this allows a class to inherhit attritubes and methods from another class
# - it helps in code reusbality and exentabaility

# %%
class Animal:
    def __init__(self, name):
        self.name = name
        self.is_alive = True

    def sleep(self):
        return f"{self.name} is sleeping"

    def eat(self):
        return f"{self.name} is eating"

class Dog(Animal):
   def speak(self):
       return f"{self.name} woof!"

class Cat(Animal):
    def speak(self):
        return f"{self.name} meow!"

class Mouse(Animal):
    def speak(self):
        return f"{self.name} squeak!"

dog = Dog("fred")
cat = Cat("alfred")
mouse = Mouse("kannabi")

print(dog.name)
print(cat.name)
print(mouse.name)

print(dog.sleep())
print(cat.eat())
print(dog.eat())
print(mouse.sleep())
print(mouse.speak())
print(dog.speak())
print(cat.speak())
print(mouse.speak())
# Out:
# fred
# alfred
# kannabi
# fred is sleeping
# alfred is eating
# fred is eating
# kannabi is sleeping
# kannabi squeak!
# fred woof!
# alfred meow!
# kannabi squeak!

# %% [markdown]
# #### multiple and multi level inhertance
# - muiltple is where a class can inhert from another class
# - muiti level inhertance is where by a a class can inherit from another clas which inherits from anouther class like grand parents

# %% [markdown]
# - mutliple inhertance

# %%
class Animal:
    def __init__(self, name):
        self.name = name 
    
    def sleep(self):
        return f"{self.name} is sleeping"
    
    def eat(self):
        return f"{self.name} is eating"
    
class prey(Animal):
    def runs(self):
        return f"{self.name} runs"
class predator(Animal):
    def hunt(self):
        return f"{self.name} hunts"
    
class rabbit(prey, ):
    def jump(self):
        return f"{self.name} jumps"
class fox(predator):
    def foxes(self):
            return f"{self.name} foxes"
class fish(prey, predator):
    def swims(self):
            return f"{self.name} swims"


rabbit = rabbit ("fred")
fox = fox("alfred")
fish = fish ("morgan")

rabbit.sleep()
fish.swims()
# Out:
# 'morgan swims'
